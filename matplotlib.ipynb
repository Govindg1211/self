# %%
import matplotlib.pyplot as plt

x = ["part1","part2","part3","part4","part5"]
y = [55,45,78,32,62]

plt.bar(x,y)
plt.xlabel("parts of the data")
plt.ylabel("popularity")
plt.title("distribution of popularity")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:/excel raw data/minor data/crime.csv")
df = pd.DataFrame(data)
print(df)
group = df.groupby("Year")["Murder"].sum()
print(group)
plt.bar(group.index,group.values)
#plt.bar(df["Year"],df["Murder"])
plt.show()
# Out:
#               STATE    Year  Murder  Assault on women  \
# 0               NaN     NaN     NaN               NaN
# 1    ANDHRA PRADESH  2001.0    45.0              69.0
# 2               NaN     NaN     NaN               NaN
# 3    ANDHRA PRADESH  2002.0    60.0              98.0
# 4               NaN     NaN     NaN               NaN
# ..              ...     ...     ...               ...
# 835      PUDUCHERRY  2010.0     1.0               0.0
# 836             NaN     NaN     NaN               NaN
# 837      PUDUCHERRY  2011.0     0.0               0.0
# 838             NaN     NaN     NaN               NaN
# 839      PUDUCHERRY  2012.0     2.0               0.0
#
#      Kidnapping and Abduction  Dacoity  Robbery  Arson   Hurt  \
# 0                         NaN      NaN      NaN    NaN    NaN
# 1                        22.0      3.0      2.0    6.0  518.0
# 2                         NaN      NaN      NaN    NaN    NaN
# 3                        18.0      0.0      4.0   12.0  568.0
# ...

# %% [markdown]
# ### line plot

# %%
x = ["day1","day2","day3","day4","day5"]
y1 = [280,540,350,500,245]
y2 = [500,300,275,450,350]

plt.plot(x,y1, marker = "*", ls = "--", color = "red", label = "week1")
plt.plot(x,y2, marker = "^", ls = "-", color = "green", label = "week2")
plt.legend()
plt.show()

# %%
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(data)
print(df)
group = df.groupby("name")["protein"].sum()
print(group.head(30))
print()
plt.plot(df["name"],df["rating"])
print(df)
plt.show()
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ## scatter plot

# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.random.randint(1,10,50)
y = np.random.randint(10,100,50)
color = np.random.randint(10,100,50)

plt.scatter(x,y,marker = "*", cmap = "rainbow", c = color)
plt.colorbar()
plt.show()

# %%
 import pandas as pd

data = pd.read_csv("sales.csv")
df = pd.DataFrame(data)
print(df)
plt.scatter(df["Dist_Taxi"], df["Observation"])
plt.show()
# Out:
#      Observation  Dist_Taxi  Dist_Market  Dist_Metro  Store_Area  \
# 0              1     9796.0       5250.0     10703.0      1659.0
# 1              2     8294.0       8186.0     12694.0      1461.0
# 2              3    11001.0      14399.0     16991.0      1340.0
# 3              4     8301.0      11188.0     12289.0      1451.0
# 4              5    10510.0      12629.0     13921.0      1770.0
# ..           ...        ...          ...         ...         ...
# 927          928    12176.0       8518.0     15673.0      1582.0
# 928          929     7214.0       8717.0     10553.0      1387.0
# 929          930     7423.0      11708.0     13220.0      1200.0
# 930          931    15082.0      14700.0     19617.0      1299.0
# 931          932     9297.0      12537.0     14418.0      1174.0
#
#      Items_Available       Parking Coupon_Category  Daily_Customer_Count  \
# 0             1961.0          Open           CAT B                   530
# ...

# %% [markdown]
# ## pir chart

# %%
brands = ["oneplus","samsung","vivo","oppo"]
x = [20,30,12,28]

plt.pie(x, labels = brands, )
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(df)
plt.pie(df["fat"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 5
# ...

# %% [markdown]
# ## box plot

# %%
l = [12,23,34,45,14,25,46,35,47,59,24,15,36,58,65,10]

plt.boxplot(l)
plt.show()

# %%
l1 = [1,3,4,7,12,2,8,9,24]
l2 = [2,3,4,6,3,5,7,3,6]

values = [l1,l2] # this will print 2 boxplots simultaniously
plt.boxplot(values)
plt.show()

# %%
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(data)

plt.boxplot(df["calories"])
plt.show()

# %% [markdown]
# ## histogram

# %%
data = [19,3,4,7,12,2,8,9,24.45,20,26,29,17,19,23,25,15]

plt.hist(data, bins = 30, edgecolor = "cyan", color = "teal") # bins is the division of the data the number given here, the size of the individual bar will be whole/bins
plt.show()

# %%
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(data)

plt.hist(df["mfr"], bins = 10)

# %% [markdown]
# ## violin plot

# %%
data = [19,3,12,2,8,9,24,12,20,16,17,19,23,25,15,15,15,15]

plt.violinplot(data, showmedians = True)
plt.show()

# %%
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(data)

plt.violinplot(df["calories"], showmedians = True)
plt.show()

# %% [markdown]
# ## stem plot

# %%
data = [19,3,12,2,8,9,24,12,20,16,17,19,23,25,15,15,15,15]

df = pd.DataFrame(data)
plt.stem(df, orientation = "horizontal") # orientation is by default vertical
plt.show()

# %%
data = pd.read_csv("D:/excel raw data/minor data/cereal.csv")
df = pd.DataFrame(data)

df2 = (df.head(50))
plt.stem(df2["calories"])
#plt.plot(df2["calories"])
plt.show()

# %% [markdown]
# ## stack plot

# %%
days = [1,2,3,4,5,6,7]

np1 = [15,42,45,36,25,42,22,]
np2 = [51,15,25,36,41,20,43]
np3 = [24,35,26,15,45,32,42]

plt.stackplot(days, np1,np2,np3)
plt.show()

# %% [markdown]
# ## step plot

# %%
x = ["d1","d2","d3","d4","d5","d6"]
y = [45,62,78,65,85,56]

plt.step(x,y, where = "post")
plt.show()

# %% [markdown]
# ## subplot

# %%
x = [1,2,3,4,5]
y = [45,34,25,63,42]
plt.subplot(1,3,1)
plt.plot(x,y)
plt.show()

x1 = [6,7,8,9,10]
y1= [54,21,65,32,75]
plt.subplot(1,3,2)
plt.stem(x1,y1)
plt.show()

x2 = [11,12,13,14,15]
y2 = [45,85,65,35,45,]
plt.subplot(1,3,3)
plt.bar(x2,y2)
plt.show()

# %%
x = [1,2,3,4,5]
y = [45,34,25,63,42]
plt.subplot(2,2,1) # rows, columns, chartnumber
plt.plot(x,y)
plt.show()

x1 = [6,7,8,9,10]
y1= [54,21,65,32,75]
plt.subplot(2,2,2)
plt.stem(x1,y1)
plt.show()

x2 = [11,12,13,14,15]
y2 = [45,85,65,35,45,]
plt.subplot(2,2,1)
plt.bar(x2,y2)
plt.show()

x3 = [11,12,13,14,15]
y3 = [45,85,65,35,45,]
plt.subplot(2,2,2)
plt.boxplot(x3,y3)
plt.show()

# %% [markdown]
# ## saving a chart

# %%
import matplotlib.pyplot as plt

x = ["part1","part2","part3","part4","part5"]
y = [55,45,78,32,62]

plt.bar(x,y)
plt.xlabel("parts of the data")
plt.ylabel("popularity")
plt.title("distribution of popularity")
plt.savefig("bar.png") # you have to specify the extension of the image  ("name.extension")
plt.show()
